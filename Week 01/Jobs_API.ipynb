# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **JOBS API Implementation Using FLASK**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives
#
# You will be executing this code  so that the client application **Collecting Jobs API**  will be accessing this code executing on the server

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: click>=8.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (8.0.4)
# Requirement already satisfied: Werkzeug>=2.2.2 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (4.8.2)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (3.0.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->flask) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from Jinja2>=3.0->flask) (2.1.1)

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: [https://www.kaggle.com/promptcloud/jobs-on-naukricom](https://www.kaggle.com/promptcloud/jobs-on-naukricom?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01) under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %%
# !wget  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json
# Out:
# --2022-09-16 01:06:04--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12878382 (12M) [application/json]
# Saving to: ‘jobs.json.1’
#
# jobs.json.1         100%[===================>]  12.28M  58.1MB/s    in 0.2s
#
# 2022-09-16 01:06:04 (58.1 MB/s) - ‘jobs.json.1’ saved [12878382/12878382]

# %%
import flask
from flask import request, jsonify
import requests
import re

def get_data(key,value,current):
    results = list()
    pattern_dict = {
        'C'      : '(C)',
        'C++'    : '(C\+\+)',
        'Java'   :'(Java)',
        'C#'     : '(C\#)',
        'Python' :'(Python)',
        'Scala' : '(Scala)',
        'Oracle' : '(Oracle)',
        'SQL Server': '(SQL Server)',
        'MySQL Server' :'(MySQL Server)',
        'PostgreSQL':'(PostgreSQL)',
        'MongoDB'    : '(MongoDB)',
        'JavaScript'    : '(JavaScript)',
        'Los Angeles' :'(Los Angeles)',
        'New York':'(New York)',
        'San Francisco':'(San Francisco)',
        'Washington DC':'(Washington DC)',
        'Seattle':'(Seattle)',
        'Austin':'(Austin)',
        'Detroit':'(Detroit)',
        
        
        
        
        
    }
    for rec in current:
        print(rec[key])
        print(type(rec[key]))
        print(rec[key].find(value))
        #if rec[key].find(value) != -1:
        import re
        #reex_str = """(C)|(C\+\+)|(JavaScript)|(Java)|(C\#)|(Python)|(Scala)|(Oracle)|(SQL Server)|(MySQL Server)|(PostgreSQL)|(MongoDB)"""
        if re.search(pattern_dict[value],rec[key]) != None:
            results.append(rec)
    return results

app = flask.Flask(__name__)

import json
data = None
with open('jobs.json',encoding='utf-8') as f:
    # returns JSON object as
    # a dictionary
    data = json.load(f)
    
    

@app.route('/', methods=['GET'])
def home():
    
    return '''<h1>Welcome to flask JOB search API</p>'''


@app.route('/data/all', methods=['GET'])
def api_all():
    return jsonify(data)


@app.route('/data', methods=['GET'])
def api_id():
    # Check if keys such as Job Title,KeySkills, Role Category and others  are provided as part of the URL.
    #  Assign the keys to the corresponding variables..
    # If no key is provided, display an error in the browser.
    res = None
    for req in request.args:
        
        if req == 'Job Title':
            key = 'Job Title'
        elif req == 'Job Experience Required' :
            key='Job Experience Required'
        elif req == 'Key Skills' :
            key='Key Skills'
            
        elif req == 'Role Category' :
            key='Role Category'
        elif req == 'Location' :
            key='Location'
        
        elif req == 'Functional Area' :
            key='Functional Area'
        
        elif req == 'Industry' :
            key='Industry'
        elif req == 'Role' :
            key='Role'
        elif req=="id":
             key="id"
        else:
            pass
    
        value = request.args[key]
        if (res==None):
            res = get_data(key,value,data)
        else:
            res = get_data(key,value,res)

    # Use the jsonify function from Flask to convert our list of
    # Python dictionaries to the JSON format.
    return jsonify(res)

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# [2022-09-16 01:08:37,468] ERROR in app: Exception on /data [GET]
# Traceback (most recent call last):
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/tmp/wsuser/ipykernel_520/2048954028.py", line 99, in api_id
#     value = request.args[key]
# UnboundLocalError: local variable 'key' referenced before assignment
# 127.0.0.1 - - [16/Sep/2022 01:08:37] "GET /data?description=Python&page=1 HTTP/1.1" 500 -
# [2022-09-16 01:16:27,791] ERROR in app: Exception on /data [GET]
# Traceback (most recent call last):
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/flask/app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/tmp/wsuser/ipykernel_520/2048954028.py", line 99, in api_id
#     value = request.args[key]
# UnboundLocalError: local variable 'key' referenced before assignment
# 127.0.0.1 - - [16/Sep/2022 01:16:27] "GET /data?description=Python&page=1 HTTP/1.1" 500 -
# Media Planning| Digital Media
# <class 'str'>
# -1
# pre sales| closing| software knowledge| clients| requirements| negotiating| client| online bidding| good communication| technology
# <class 'str'>
# -1
# Computer science| Fabrication| Quality check| Intellectual property| Electronics| Support services| Research| Management| Human resource management| Research Executive
# <class 'str'>
# -1
# Technical Support
# <class 'str'>
# -1
# manual testing| test engineering| test cases| web testing| web technologies
# <class 'str'>
# -1
# adobe experience manager| digital| digital marketing| adobe analytics| data analytics| aem| adobe| sitecatalyst
# <class 'str'>
# -1
# channel partners| real estate| negotiation| property| Residential Sales
# <class 'str'>
# -1
# TFS| Azure| Git| VSTS| Docker| DynaTrace| Splunk| AWS
# <class 'str'>
# -1
# Bde
# <class 'str'>
# -1
# technical support| support services| application support| communication skills| voice based process| semi voice| semi voice process
# <class 'str'>
# -1
# secretary| executive assistant| ea
# <class 'str'>
# -1
# website| web analytics| xml| link building| google analytics| case studies| seo| social media| tracking| maintaining
# <class 'str'>
# -1
# operations| workflow| tat| monitoring| mts| email
# <class 'str'>
# -1
# Oracle IDAM|OIM|OAM
# <class 'str'>
# -1
# digital marketing| seo| social media marketing| content marketing| email marketing| sem| google analytics| campaign management| facebook| media management
# <class 'str'>
# -1
# Help Desk| Customer Service| customer relationship| access controls| Asset Management| Vendor Management
# <class 'str'>
# -1
# Report Generation| Policies| analytical| procedures| Analysts| Data Entry| analytical skills
# <class 'str'>
# -1
# Copyright| Email| jQuery| XML| Javascript| CakePHP| Customer service| Open source| Facebook| CSS3
# <class 'str'>
# -1
# C#| MS Dynamics CRM| Microsoft Dynamics| ms dynamics
# <class 'str'>
# -1
# sales manager| business development manager| relationship manager| brokers| insurance sales| channel sales| direct sale| direct marketing| sales| Marketing Executive| Territory Sales Manager
# <class 'str'>
# -1
# lead generation| business development| corporate sales
# <class 'str'>
# -1
# contract management| closing| it services| relationship building| managed services| selling| market research| business development manager| sales
# <class 'str'>
# -1
# QA Executive
# <class 'str'>
# -1
# Java EE| JMS| Core Java| JUnit| Weblogic| HTML| JPA| JSON| SOAP| SQL
# <class 'str'>
# -1
# Conceptualization| Architecting| Continuous improvement| SIDE| development| Front end| it
# <class 'str'>
# -1
# Articulate Storyline
# <class 'str'>
# -1
# Area Sales Management| Retail Sales| FMCG| Chocolate| confectionary| ASM| Area Sales Manager| area business manager
# <class 'str'>
# -1
# C#| Java| OOP| C++| Multithreading| UML| OOAD| OOPS| .Net| debugging
# <class 'str'>
# -1
# qmail| workflow| nagios| windows server| networking| mysql| monitoring| redhat| maintaining| centos
# <class 'str'>
# -1
# Java| JPA| Hibernate| Project Management| JDBC| Scrum Master| Microservices| Agile| SOAP| Rest
# <class 'str'>
# -1
# Java| java api| Banking| j2ee| API| finance| core java| microservices
# <class 'str'>
# -1
# GIS| ISO 27001| HR| information system| process| ISO 9001| Information security management| GIS software| Management| Edge
# <class 'str'>
# -1
# Administration| Administrative Support| Contract Logistics| Staff Development| Site Management| Quality Improvement| warehousing| Warehouse Operations
# <class 'str'>
# -1
# filing| tds| service industry| pf| esi| returns| coaching| payroll| invoice| tally
# <class 'str'>
# -1
# Outbound| Antivirus| Technical support| Sales| Spot| Inbound calls| pay| Medical| Comp
# <class 'str'>
# -1
# Troubleshooting| DNS| DHCP| Monitoring| Virtualization| Shell scripting|Python| VMS| Open source| Archiving
# <class 'str'>
# 72
# 4G| 3GPP| 3G| System Architect| LTE| Radio Access Network| PhD| IEEE
# <class 'str'>
# -1
# arm processor|c|device drivers|embedded linux|linux kernel|ipc
# <class 'str'>
# -1
# market| presentation| strong analytical skills| english| presentation skills| developing| customer interaction
# <class 'str'>
# -1
# fixed assets| accounts payable| record to report| general accounting| general ledger
# <class 'str'>
# -1
# Team management| Regional sales| Management
# <class 'str'>
# -1
# Commercial Activities| Commercial Sales| Online Sales| Senior Management| Budgeting| Strategy Implementation| Marketing| E - commerce
# <class 'str'>
# -1
# ODI| Matrix
# <class 'str'>
# -1
# javascript| sql| php| php mysql| css| software development| technical| photoshop| mca| ajax| jquery| application| web| design| mysql| html
# <class 'str'>
# -1
# Relationship management| Relationship building| Client relationship| Training| Analytical skills| Process mapping| Standard operating procedures| Agile| Management| Visa processing
# <class 'str'>
# -1
# android| btech| iphone| server| analytical| developing| ios| platforms| objective c| web| xml| design| json| programming| development| c| testing| mobile| xcode| application development| eclipse| application| sdk| applications
# <class 'str'>
# -1
# cca| bpo| csr| international bpo| customer service| outbound process| customer care| tourism| customer support| fresher| voice process| inbound process| cse| bpo fresher| voice support| hotel| travel
# <class 'str'>
# -1
# bca| graphics| application development| b tech| core| b sc| application| b e| ios| publishing| animation
# <class 'str'>
# -1
# Accounting| Continuous Improvement| Process Improvement| Load Balancing| Lean Six Sigma| Black Belt| Training| Green Belt| Process re - engineering| Process Excellence| Business Excellence| OTC
# <class 'str'>
# -1
# Automobile| Digital Content| Content Development| Production| Web Content Writing
# <class 'str'>
# -1
# Tourism| target achievement| negotiation skills| revenue management| Tour Packages
# <class 'str'>
# -1
# PHP| Networking| Data structures| HTTP| JSON| Software design| Computer science| System design| Backend| Ticketing
# <class 'str'>
# -1
# WebLogic| configuration| MySQL| installation| Oracle DBA| troubleshooting| Oracle RAC
# <class 'str'>
# -1
# Service level| Data management| HR Coordinator| Management audit| HR operations| Human resource management
# <class 'str'>
# -1
# Graphics| C++| Windows OS| Linux| high performance computing| Test cases| System software| Gaming| FreeBSD
# <class 'str'>
# -1
# Sales| Team Building| Strategic Leadership| Real Estate| Field Sales| Sales Strategy| Enterprise Business| Go - to - market Strategy| Enterprise sales| Sales Executive Activities| Marketing
# <class 'str'>
# -1
# Facility Management| facility services
# <class 'str'>
# -1
# sds| radiology| CPT| icd - 10| EM| medical coding| coders| surgery| ed
# <class 'str'>
# -1
# Market analysis| Public relations| CV| Relationship building| Market intelligence| Prospecting| Budgeting| Sales process| Branding
# <class 'str'>
# -1
# ERP| MIS| Succession Planning| Reports| Talent Management| Human Resources| HR Policies| Recruitment| Talent Acquisition
# <class 'str'>
# -1
# revenue generation| marketing| ad sales| web technologies
# <class 'str'>
# -1
# co ordination| team management| drafting| loans| online| coordination| quality
# <class 'str'>
# -1
# English| PHP| XML| DOM| SOAP| Com| Web technologies| Written communication| Email| Time
# <class 'str'>
# -1
# cloud| puppet|Python| git| KVM| linux| jenkins| openstack| ansible
# <class 'str'>
# 14
# National| Branch| Vice President| J2Ee| Software
# <class 'str'>
# -1
# Mentor| Android| Consulting| Usage| development| software| mobile| it| SIDE| Front end| Web technologies| Coding| web| backend| Open source| programming| Investment
# <class 'str'>
# -1
# Performance Testing| Software Testing| Manual Testing| Quality Testing
# <class 'str'>
# -1
# international bpo| bpo| kpo| web chat| non voice process| e mail| international call center| customer service representative| cse| interpersonal skills| ites| uk shift| customer service| e - commerce| customer care| customer support| bpo fresher
# <class 'str'>
# -1
# Innovative| Aggressive
# <class 'str'>
# -1
# Communication Skills| Detail Engineering| Material Handling| AutoCAD| Detailing| Design Engineering| Microstation| Bid Evaluation
# <class 'str'>
# -1
# design| android| erp| software| mvc| quality
# <class 'str'>
# -1
# Technical Writing| Technical Documentation| Articles| Writing Skills| Product Support
# <class 'str'>
# -1
# Ansys| thermal| MATLAB| System design| Recruitment| MCCB| Electricals
# <class 'str'>
# -1
# Product placement| Market research| Distributor handling| Business Development Executive| Customer service| Customer Service Executive| Secondary sales| Supervision
# <class 'str'>
# -1
# Management accounting| Accounting| VAT| Book Keeping| SAGE| Tax returns
# <class 'str'>
# -1
# Trade| Forex Trading| Forex| fx| Lead Generation| Accounting| Banking| Revenue Generation| Current Account
# <class 'str'>
# -1
# XML| Javascript| PHP| development| css| technical| analytical| software| testing| HTML| tools| Joomla| coding| jQuery| web| MySQL| Wordpress| design| XHTML| debugging| Ajax
# <class 'str'>
# -1
# zld| Engineering Management| knitting
# <class 'str'>
# -1
# Analyst| ERP| Change management| Business objects| Managed services| Business process mapping| Executive management| Data mining| oracle project accounting| Testing
# <class 'str'>
# -1
# ERP| Succession Planning| MIS| Reports| Talent Management| Human Resources| HR Policies| Recruitment| Talent Acquisition
# <class 'str'>
# -1
# Intern| Linux| Windows| Unix| DNS| C++| Perl| IIS| Redhat| HTTP
# <class 'str'>
# -1
# C| Woocommerce| Magento| Wordpress| MySQL| PHP| Shopify| JQuery| Web Development| Ajax
# <class 'str'>
# -1
# CSS| Singleton| XML| Javascript| JDBC| Struts| JSON| HTML| Spring Boot| JQuery
# <class 'str'>
# -1
# Business Development Management| Bd| Marketing| business development| Projects| business development manager| bdm| Tendering| Proposal
# <class 'str'>
# -1
# Ethical Hacking| Certified Ethical Hacker| Networking Protocols| Penetration Testing| Nessus| NMAP| Fortify| Vulnerability Assessment| Appscan| Qualys
# <class 'str'>
# -1
# Graphic designing| Graphics| adobe creative suite| Architecture| MS Office| Business Executive
# <class 'str'>
# -1
# Payment collection| Costing| Business Development Executive| Lead generation| Sales| Vendor| Cost
# <class 'str'>
# -1
# Internship| Digital marketing| Social media| Relationship building| Animation| Creative| Indesign| Business Executive| Presentation skills| Senior
# <class 'str'>
# -1
# market penetration|marketing|customer satisfaction|enterprise business|web technologies|business development|strategy|aws|sales
# <class 'str'>
# -1
# jquery| git| microsoft sql server| net asp net| software| testing| ado.net| microsoft| tools| sql| unit tests| database| application| web| design| .net| object oriented programming| support| programming
# <class 'str'>
# -1
# technical recruitment| us staffing| us recruitment| us recruiter| us it staffing| technical recruiter| it recruiter| recruiter| w2| c2c| talent acquisition| recruitment| staffing| sourcing
# <class 'str'>
# -1
# Project Administration| Coordination
# <class 'str'>
# -1
# Order Management system| Sterling Commerce| Sterling| OMS| Sterling Integrator| ecommerce| E - commerce
# <class 'str'>
# -1
# analytical| documentation| web development| algorithms| development| javascript| sql server| jquery| database| web| flex| design| mysql| net
# <class 'str'>
# -1
# NCTVT
# <class 'str'>
# -1
# Drupal| Application programming| MySQL| Wordpress| PHP| CakePHP| Team Leader| MVC| Zend| Software services
# <class 'str'>
# -1
# Outbound| Sales| Project management| Analytical| Sales Lead| Automation tools| Sales process| marketing automation
# <class 'str'>
# -1
# AutoCAD| 3D Modeling| FMEA| Mechanical Engineering| Mechanical Design| SolidWorks
# <class 'str'>
# -1
# Automation Engineer
# <class 'str'>
# -1
# Revenue Cycle Management| US Healthcare| Payment Posting| Medical Billing| Medical Coding| us visa| Team Leading Skills| Healthcare| Denial Management| RCM
# <class 'str'>
# -1
# Voice process| qaqc| Writing| Process operations| Verbal
# <class 'str'>
# -1
# Predictive Modeling| SAS| Data Management| Data Mining| Tableau| Data Analytics| Statistics| Analytics| SQL|Python
# <class 'str'>
# 108
# molecular biology| chemistry| biotechnology| bhms| biology| Physiotherapy| microbiology| nursing| biomedical| Physics| medical coding| biochemistry| pharmacy| Ophthalmology| micro biology| Bioinformatics| zoology| biotech
# <class 'str'>
# -1
# accounts executive| accountant| Stock Management| gst| auditing| Statutory Compliance| accounting| Account Assistant| Bank Reconciliation| tax audit| banking| monthly reports| Payroll| salary processing| income tax| Income Tax Return| taxation
# <class 'str'>
# -1
# Informatica Power Center| Informatica
# <class 'str'>
# -1
# digital marketing| seo specialist| advertising agency| online marketing| seo| seo expert| facebook marketing
# <class 'str'>
# -1
# Validation| Installation| Breakdown Maintenance| Industrial Safety| gmp| Boiler| Design| HVAC| Gensets| Air Compressor| Breakdown| RO| who
# <class 'str'>
# -1
# Forecasting
# <class 'str'>
# -1
# Pay Per Click| Google AdWords| Search Engine Marketing| PPC| SEM| Google Analytics| Website Analysis| Yahoo| Web Analytics| Marketing Initiatives
# <class 'str'>
# -1
# marketing officer| pharma sales| Marketing Representative| marketing executive| pharma marketing| sales officer| sales representative| business development executive| Fresher| trainee| sales executive
# <class 'str'>
# -1
# Project management| PPAP| Automotive| External audit| Conflict resolution| Resource mobilization| PFMEA| Risk management| Project life cycle
# <class 'str'>
# -1
# PR| Public Relations| Media Relations| Social Media| Marketing Communication| corporate communication| media relation| corp comm| Online Media| public relation| Journalism| Advertising| mass communication
# <class 'str'>
# -1
# counselling| couselling| fresher| student counsellor| student counseling
# <class 'str'>
# -1
# Help Desk| Customer Service| customer relationship| access controls| Asset Management| Vendor Management
# <class 'str'>
# -1
# asp dot net| .net developer| Dot Net Developer| asp.net| asp . net
# <class 'str'>
# -1
# Secondary Research| Valuation| Finance| Real Estate| Primary| Report Preparation| Business Development| Due Diligence| Financial Modelling
# <class 'str'>
# -1
# Teaching| Educator| Counselor| Mentor| Trainer| Advisor
# <class 'str'>
# -1
# X - Ray| Medical Transcription| Ultrasound| CT Scan
# <class 'str'>
# -1
# cms| javascript| wordpress| drupal| joomla| ajax| cakephp| zend| knowledge| xhtml
# <class 'str'>
# -1
# Sales| Management| Sales management| Educational sales
# <class 'str'>
# -1
# Outbound| Antivirus| Technical support| Technical Support Associate| process| Sales| Inbound calls| US shift| Comp
# <class 'str'>
# -1
# Technical support| English| Comp| Customer Care Executive| Inbound calls| Antivirus| Issue| Software
# <class 'str'>
# -1
# C#|Application Development|Senior Level|MS SQL|Visual Basic|Power Bi|MSBI|SSIS|Recruitment|Data Integration
# <class 'str'>
# -1
# Escalation management| Field Sales Executive| Sales achievement| Training| Insurance sales
# <class 'str'>
# -1
# Team management| Salesforce| Usage| Sales| Skill development| Training| Productivity improvement| Training management| Sales budgeting| TSI
# <class 'str'>
# -1
# Networking| Unix| Change management| Scheduling| Publishing| Incident management| VMware| Problem management| Remedy| SIP
# <class 'str'>
# -1
# planning| training| training manager| trainer| faculty
# <class 'str'>
# -1
# Sales| Billing| MS Office| Business reporting| Insurance sales| MIS preparation| Usage| Corporate| Networking| Retail
# <class 'str'>
# -1
# customer support| support service| field support| team| management| supervisor| self motivated| continuous improvement| give| enthusiastic
# <class 'str'>
# -1
# Javascript| SQL| XML| server| css| technical| software| developing| HTML| tracking| database| web| Application development| net| programming| Ajax| development| DOM| solid| data integrity| Stored procedures| Reporting tools| application| applications
# <class 'str'>
# -1
# Senior Design Engineer| Engineering Design| SACS
# <class 'str'>
# -1
# C|Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems
# <class 'str'>
# 2
# Technical Support Executive| Electrical engineering
# <class 'str'>
# -1
# Data analysis| Automation| Google Analytics| Excel| Analytical| Business intelligence| Analytics| Product marketing| SQL| Data extraction
# <class 'str'>
# -1
# Detail Design|Juniper|SMSC Engineer|Routing|IP Networking|Network Elements|Network Troubleshooting|High Level Design|Data Center|Switching
# <class 'str'>
# -1
# assistant restaurant manager| restaurant| restaurant manager
# <class 'str'>
# -1
# layout| visualization| digital media| graphic design| html| illustration| tools| part time
# <class 'str'>
# -1
# selling| accounts| events| prospecting| business operations| ideas| coordinating| tracking| closing| maintaining
# <class 'str'>
# -1
# photoshop| illustrator| seo| jquery| fireworks| css3| gui| usability| development| static
# <class 'str'>
# -1
# Photoshop| HTML| Wordpress| CSS3| bootstrap| Web technologies| html5| CSS
# <class 'str'>
# -1
# Python
# <class 'str'>
# 0
# server| multimedia| troubleshooting| graphics| audio| monitoring| javascript| jquery| user interface| css3
# <class 'str'>
# -1
# Senior management| MIS reporting| Building| Training| Management| Risk| Vice President| Focus| Trade| Associate Vice President
# <class 'str'>
# -1
# Sales Head| Tied Channel| Sales| Business Growth| Profitability| Business Operations| New Business| Alliances
# <class 'str'>
# -1
# Project Management
# <class 'str'>
# -1
# QA| Life Sciences| development quality assurance| Life Cycle| Regulatory Affairs| DQA| QMS| Dmf
# <class 'str'>
# -1
# accounting| finance| financial reporting| statutory compliance| gst| vat
# <class 'str'>
# -1
# Data analysis| Consumer research| Management| Head Business Development
# <class 'str'>
# -1
# Testing| Quality| Manual Testing| ETL| BI| DW| Datawarehouse Testing
# <class 'str'>
# -1
# assembly language| Six Sigma| PMP| C| JavaScript| .NET| HTML| Oracle|Python| SQL
# <class 'str'>
# 69
# Product management| Business process| Linkedin| Automation| CV| Email| GIT| Technical| SDLC| Ideas
# <class 'str'>
# -1
# ajax| javascript| php| erp| website| development| software development| module| mca| application development| application| web| programming
# <class 'str'>
# -1
# customer service| customer care| team| communication| bpo| call center| inbound| voice| backend| non voice| telecalling| cse| cro| cce| data entry| back office| voice process| domestic bpo| fresher| trainee| Telemarketing| Outbound| sales| hardware| networking
# <class 'str'>
# -1
# Oracle|Core Java|Business process|Outsourcing|Operations|spring integration|J2Ee|Spring framework|JEE|Manager Technology
# <class 'str'>
# -1
# MS Office| Data entry
# <class 'str'>
# -1
# Customer relationship| Automobile| Proposal preparation| CRM strategy| Architecture| Database| Testing
# <class 'str'>
# -1
# Unix| Version control| Prototype| XML| MySQL| PHP| JSON| MVC| Ajax| CSS3
# <class 'str'>
# -1
# Merchandising| Buyer Activities| Follow Ups| Vendor| purchase| vendor development| tracking
# <class 'str'>
# -1
# C#| Azure| Powershell| Script Writing| API| Debugging| Devops| Application Integration
# <class 'str'>
# -1
# operations management| mobilization| Resource Mobilization| general management| interview| Recruitment
# <class 'str'>
# -1
# Customer Support Executive| Customer service| Business Executive| process
# <class 'str'>
# -1
# Staff Training| Day Care| Recruitment
# <class 'str'>
# -1
# process| Spot| Technical support| Night shift| International BPO
# <class 'str'>
# -1
# digital marketing|email marketing|adwords|display advertising|digital campaigns|google analytics|sem|seo
# <class 'str'>
# -1
# java| cisco call manager| visa| j2ee| sip| offshore| communication skills
# <class 'str'>
# -1
# Sales| Business Development| Change Management| Mobile| mobiles| handset| mobile handset| Marketing| Relationship Management| Distribution Management| channel management| dealer management| Retailer
# <class 'str'>
# -1
# International Call Center| Technical Support| Maintenance| Communication Skills| PC Hardware| Technician Activities| Social Media| Analytical Ability| Soft Skills| Customer Satisfaction
# <class 'str'>
# -1
# Illustrator| Corel Draw| Photoshop
# <class 'str'>
# -1
# Manual testing| Informatica| microsoft| Process automation| System testing| PDF| Artificial Intelligence| Regression testing| Silicon| Analytics
# <class 'str'>
# -1
# Technical Architecture| Fusion| Oracle Fusion
# <class 'str'>
# -1
# Layout design| Corel Draw| Web designing| Photoshop
# <class 'str'>
# -1
# Bpo Voice| Voice Process| International BPO
# <class 'str'>
# -1
# HTML5| ASP
# <class 'str'>
# -1
# Product training| Sales| Relationship| Banking| Recruitment
# <class 'str'>
# -1
# Customer profitability| Receivable management| Education| Relationship building| Transportation| Service| Monitoring| Key accounts
# <class 'str'>
# -1
# Stores| warehouse| Logistics
# <class 'str'>
# -1
# BPO| Outbound| English| Email| Inbound calls| Customer service| Troubleshooting| Technical support| Recruitment| Comp
# <class 'str'>
# -1
# Linux| Agile|Python| Computer science| Coding| Fixed income| Machine learning| Asset management| JIRA| Financial services
# <class 'str'>
# 13
# English| MS Office| admin executive| Billing| Stock inventory| Writing| Office management| Management| Business Executive| Application
# <class 'str'>
# -1
# Credit Officers| Risk Management| Administration| Report Generation| Analysts| analytical skills
# <class 'str'>
# -1
# Balance Sheet Finalisation| service tax| bank reconciliation| gst| income tax| taxation| financial auditing| finance| tax audit
# <class 'str'>
# -1
# accounts payable| accounting| AP
# <class 'str'>
# -1
# Change management| Healthcare| Analyst| Business Analyst| Social media| Problem management| Software development life cycle| Scheduling| OEE
# <class 'str'>
# -1
# Copyright| Customer Service Representative| CV| Customer service| Security| Troubleshooting| CCTV
# <class 'str'>
# -1
# CSS| jQuery| MySQL| Javascript| HTML| Web Development| Laravel| Codeigniter
# <class 'str'>
# -1
# Networking| Telecom| LAN| WAN| Bss| VPN| Wireless| Telecommunication| Costing| Visio
# <class 'str'>
# -1
# Teaching| Educator| Counselor| Mentor| Trainer| Advisor
# <class 'str'>
# -1
# Business communication| Analytical skills| Business objects| Team management| management| Transition management| Trend analysis| Variance analysis| Analytics
# <class 'str'>
# -1
# Usage| PDF| C| Social media| Cash handling| Database| Customer service| Merchandising| Advertising
# <class 'str'>
# -1
# salesforce| salesforce.com| system design| application architecture
# <class 'str'>
# -1
# Execution|Project Management|AO engagement|Monitoring Tools|Delivery Management|Stakeholder Management|System Monitoring
# <class 'str'>
# -1
# Recruitment| Hiring| HR| Screening| Interviewing| Staffing
# <class 'str'>
# -1
# bca| cold calling| bidding| academic| customer service| documentation| selling| web development| seo| mba
# <class 'str'>
# -1
# Java| Webservices| Spring| Hibernate| System Design| ESB| SQL| Spring Boot| Javascript
# <class 'str'>
# -1
# Debugging| Troubleshooting|Python| Interpersonal skills| OOPS| Programming| developer
# <class 'str'>
# 27
# Direct sales| Cold calling| English| Networking| Business Development Manager| Customer interfacing| Data collection| Service| Digital marketing| WHO
# <class 'str'>
# -1
# build automation| Entity framework| MVC| microsoft| SQL
# <class 'str'>
# -1
# Technical support| Outbound| Troubleshooting| RecruitmentEnglish| Antivirus| Comp| Customer Service Executive| Domestic BPO
# <class 'str'>
# -1
# Outbound| Medical| Technical support| Technical Support Associate| Email| Sales| US shift| Antivirus| Troubleshooting| Comp
# <class 'str'>
# -1
# HR| Human Resource Management| Placement Coordination| recruitment executive| recruitment officer
# <class 'str'>
# -1
# Strategic Sourcing| procurement| supply chain management| Packaging| Vendor Management
# <class 'str'>
# -1
# Test Engineering
# <class 'str'>
# -1
# Outbound| Technical Support Associate| Sales process| process| Senior| Technical| US shift| Technical support| International BPO
# <class 'str'>
# -1
# Corporate Training| corporate trainer| technical trainer
# <class 'str'>
# -1
# java| mongodb| Hibernate| spring| jms
# <class 'str'>
# -1
# Procurement| Supply chain management| Automation| Copyright| Chain| Purchase| Head Operations| Steel| Business Executive
# <class 'str'>
# -1
# software development life cycle| css| html5| ui development| design patterns| svn| software engineering| angularjs| javascript
# <class 'str'>
# -1
# good communication skill| good speeking manners| ability to face strangers| punctual| gopod efficiency
# <class 'str'>
# -1
# Cash Handling| Cashier Activities| Day Book| Cashier| Restaurant| CSAT
# <class 'str'>
# -1
# C#| .Net| Asp.net
# <class 'str'>
# -1
# Excel| Sales| Conflict resolution| Analytical| Management Trainee| Power point presentation| MS Office
# <class 'str'>
# -1
# Manual testing| Eclipse| Coding| Scrum| Enterprise applications| Healthcare| JIRA| Android SDK| test driven development| Business Analyst
# <class 'str'>
# -1
# Production Management| production control| production planning| Production Manager| Planning| Production Support| Organizing
# <class 'str'>
# -1
# Outbound| Medical| Technical support| Technical Support Associate| Email| Technical| US shift| Antivirus| Troubleshooting| Comp
# <class 'str'>
# -1
# Digital media| PHP| Recruitment| Bengali| LMS| Business administration| Content Editor| Journalism| Literature| Administration
# <class 'str'>
# -1
# Graphics| Simulation| Power management| Electronics| Hardware| Research| System analysis| Electricals
# <class 'str'>
# -1
# Motion Graphics| Infographics| Illustrator| animations| infographics| Corel draw| Photoshop| CorelDRAW| Visual Designer
# <class 'str'>
# -1
# Illustrator| Web designing| Photoshop| CSS| Web technologies| XML| Intranet| Business Executive
# <class 'str'>
# -1
# Tally| Retail| Accounts Executive| Retail Executive
# <class 'str'>
# -1
# Financial reporting| Due diligence| Data analysis| Accounting| International finance| Banking
# <class 'str'>
# -1
# NSE| Lead generation| Compliance| Relationship| Equity| Client acquisition| Research| Revenue generation| Monitoring| HNI client handling
# <class 'str'>
# -1
# MySQL| Javascript| UML| server| css| Technical writing| html5| bootstrap| microsoft| Technical support| sql| cloud| ui| web| design| asp.net| mvc| api| architecture| level| Visual Studio| quality| MS SQL| infrastructure| .net| agile| angularjs| aws
# <class 'str'>
# -1
# MIS reporting| Trade| Operational risk| Banking| Relationship| Client relationship| Saving
# <class 'str'>
# -1
# sales strategy| sales management| B2B Sales| corporate sales| institutional sales
# <class 'str'>
# -1
# soa| sql| relationship management| server| software| jquery| service oriented architectures| quality systems| software implementation| computer science| sql server 2008| design
# <class 'str'>
# -1
# Art Director
# <class 'str'>
# -1
# fresher| icse| inbound process| outbound| international bpo| uk process| bcom| communication skills| back office| cbse| web chat| chat process| Aviation| Guest Relations| Public Speaking| PR
# <class 'str'>
# -1
# Outbound| Telesales| Night shift| English| process| Technical| Inbound calls| Service| Printers| Business Executive
# <class 'str'>
# -1
# Outbound| Service| Technical support| process| Inbound calls| Domestic BPO| Bonus| Business Executive| Comp
# <class 'str'>
# -1
# single sign - on| single sign on| IT Infrastructure| SSO
# <class 'str'>
# -1
# layout| coordinating| material selection| ms| mep| photoshop| corel draw| co| monitoring| plumbing
# <class 'str'>
# -1
# coding|database design|test cases|analytical|nosql|cassandra
# <class 'str'>
# -1
# accent| auditing| soft skills| training needs| customer service| process compliance
# <class 'str'>
# -1
# Sales| Fresher| Marketing
# <class 'str'>
# -1
# Java EE| Hibernate| Core Java| Software Development| Spring Mvc| Multithreading| OOD| JDBC| Spring Boot| JSF
# <class 'str'>
# -1
# Virtualization| Cloud computing| Server architecture| Windows Troubleshooting| Customer satisfaction| Manager Technology| Deployment| Management
# <class 'str'>
# -1
# business development| sales| sales marketing| marketing executive| sales executive| sales officer| sales manager| area sales manager| territory sales manager| territory manager| area manager| regional manager| regional sales manager| regional business manager
# <class 'str'>
# -1
# Sales| Sale| Networking Sales| It Solution Sales| Structured Cabling| Passive Networking| Data Center| Cable Tray| cabling| Data Center Rack| data - centre rack| LAN| UTP Cables
# <class 'str'>
# -1
# marketing executive| distributors| customer profiling| sales strategy| market research| Business Development| sales executive
# <class 'str'>
# -1
# fundraising| finance
# <class 'str'>
# -1
# worldspan| travel sales consultants| galileo| amadeus| gds
# <class 'str'>
# -1
# Front end| Email| PDF| MIN| UI| phone| Strategic HR| Doc| Consultancy| Recruitment
# <class 'str'>
# -1
# CVS| ERP| Rest| middle east| Technical| Customization| E-commerce| CRM| Open| WHO
# <class 'str'>
# -1
# Java|Angular JS|Hibernate|Core Java|Technical Leader|Technical|Javascript|Spring|JQuery|JS framework
# <class 'str'>
# -1
# senior management| ngo| key skills| Corporate Social Responsibility| Govt Liasioning| corporate pr| External Communications
# <class 'str'>
# -1
# Asp.Net MVC| entity framework| API
# <class 'str'>
# -1
# Loans| Direct Sales Associate| Policies| Bfsi| Finance| Sanction| WHO
# <class 'str'>
# -1
# Monitoring| Senior Resident| RAM| DNB| Dmc
# <class 'str'>
# -1
# Angularjs| CSS| Responsive Web Design| Javascript| Bootstrap| HTML| JSON| JQuery| Web Development| Grunt
# <class 'str'>
# -1
# Python| open source| database| Automation| java| linux| perl| Monitoring| nosql
# <class 'str'>
# 0
# PR| international bpo| chat process| Aviation| back office| web chat| Guest Relations| Public Speaking| bcom| fresher| inbound process| outbound| uk process| icse| communication skills| cbse
# <class 'str'>
# -1
# QA| Functional testing
# <class 'str'>
# -1
# Sales Engineering
# <class 'str'>
# -1
# Design Development|Software Engineering|Lighting|Computer Science|Product Quality|Automation Testing|Asset Management|GUI|Object Oriented Programming|Android
# <class 'str'>
# -1
# NAV calculation| Fund accounting| Automation| Corporate actions| Accounting| Process improvement| Analytical| Reconciliation| Standard operating procedures| Subject Matter Expert
# <class 'str'>
# -1
# Networking| Secondary research| Recruitment| Analyst| Network security| Research| IPS| Advisory| Firewall
# <class 'str'>
# -1
# hiring| HRIS| procurement| HR| sourcing| Recruitment| staffing
# <class 'str'>
# -1
# Computer science| Continuous improvement
# <class 'str'>
# -1
# pharmaceutical| medical| Pharma| medical billing| healthcare
# <class 'str'>
# -1
# CSS| Wordpress| MySQL| Javascript| PHP| HTML| JQuery| SEO| Ajax| Hosting
# <class 'str'>
# -1
# mechanical operation|preventive maintenance|mechanical|engineeringbreak down maintenance|mechanical maintenance
# <class 'str'>
# -1
# javascript| html| ajax| jquery| php mysql| smarty| api| analytical| third party| software development life cycle
# <class 'str'>
# -1
# Renewable energy|Power distribution|Power sector|Banking|Electricals
# <class 'str'>
# -1
# spanish language expert| chinese| spanish| medical
# <class 'str'>
# -1
# Sales Associate| support| Voice process| Issue| Senior| Technical| Inbound calls| Bonus| US shift| Software
# <class 'str'>
# -1
# MCSE| Database| Support Engineer
# <class 'str'>
# -1
# SSRS| SQL Server| Stored Procedures| SQL Development| MS SQL
# <class 'str'>
# -1
# GIT| Linux| Machine Learning|Python
# <class 'str'>
# 29
# GNM| Business Executive
# <class 'str'>
# -1
# institutions| relationships| marketing executive| customer| customers| implementation| company| site| product
# <class 'str'>
# -1
# Recruitment|Volume Hiring|HR|BPO Hiring|Sourcing|Interviewing|Onboarding|Staffing|Orientation|Human Resource Management
# <class 'str'>
# -1
# Java| CSS| Rest| Spring Mvc| Javascript| HTML| JPA| Spring Boot| JQuery| Web Services
# <class 'str'>
# -1
# financial analysis| financial planning| taxation| VP Finance
# <class 'str'>
# -1
# Publishing| SEO| Content management| Social media| Wordpress| Management systems| Research| Brand awareness| Web technologies| Journalism
# <class 'str'>
# -1
# Auditing| Audit Planning| Risk Assessment| Banking| Credit Risk| Credit Policy
# <class 'str'>
# -1
# c++| development| gaming| C| software| HTML| ios| opengl| iphone| design| MySQL| JavaScript
# <class 'str'>
# -1
# business development| e - commerce| sales executive| sales associate| sales officer| sales| field sales| mba fresher| fresher| new product development| channel sales
# <class 'str'>
# -1
# rest| java| sql| oop| angularjs| ui development| oracle
# <class 'str'>
# -1
# Javascript| PHP| HTML| Visualization| jQuery| web| Programming| Commerce| Web designing| Application| Android
# <class 'str'>
# -1
# Process automation| Commodity Markets| Artificial Intelligence| Market intelligence| Machine learning| Corporate| Relationship| Operations| Analytics| Robotics
# <class 'str'>
# -1
# IT Sales| Marketing Campaigns| Social Media| Btl| Marketing Management| Digital Marketing| Dealer Sales| Channel Partners| Communication Skills| Process Flow
# <class 'str'>
# -1
# Android| Troubleshooting| Middleware| Firmware| SOC| Linux kernel| Bluetooth| Computer science| Test scripts| Test strategy
# <class 'str'>
# -1
# Outbound| Antivirus| Technical support| Voice process| Technical Support Executive| US shift| Inbound voice process| Customer Service Executive| Comp| International BPO
# <class 'str'>
# -1
# Sales Executive| Cold calling| market research| customer profiling| sales executive| marketing executive| distributors| Business Development| sales strategy
# <class 'str'>
# -1
# Administration| HR| Recruitment| Recruitment Executive| IR
# <class 'str'>
# -1
# Web development| Analytics| Healthcare| Software design| Monitoring| JIRA| Computer science| Backend| Inside sales| Cloud
# <class 'str'>
# -1
# Team Management| Advisory Services| General Insurance| Sales Initiatives| Financial Products| Distributor Sales| Branch Sales| Sales Development| Motor Insurance| Marketing
# <class 'str'>
# -1
# clinical pharmacy| mr| sales officer| territory executive| business development| sales executive
# <class 'str'>
# -1
# sap| procurement| scm| material| sheetmetal| sheet metal| purchase| VD| vendor development| sourcing| BOP
# <class 'str'>
# -1
# Angularjs| CSS| Core Java| DOM| Computer Science| Javascript| HTML| Spring| Ajax
# <class 'str'>
# -1
# data analysis| Admissions| placements| Help Desk| access controls| Asset Management
# <class 'str'>
# -1
# marketing| bdm| sales| business development| it sales| ncr| hardware sales
# <class 'str'>
# -1
# Outbound| Night shift| Service| English| process| Technical| Technical support| Inbound calls| Voice process| Group
# <class 'str'>
# -1
# RT| PT| MPI| NDT Inspection| NDT Level| Diploma| Quality Inspection| Level Ii| Inspection Engineering| Mechanical Engineering| UT
# <class 'str'>
# -1
# Customer service| Healthcare| Customer relationship| Windows| Graphic designing| CAD| Illustrator| Customer satisfaction| Application software
# <class 'str'>
# -1
# BPO| any graduate| Voice Process| Voice Support
# <class 'str'>
# -1
# Outbound| Antivirus| Comp| Technical support| Technical Support Associate| technical sales associate| Sales| Technical Associate| Voice support| Inbound calls
# <class 'str'>
# -1
# Equipment Maintenance| Hydraulics| Inventory Management| Management Skills| Maintenance Head| Electricals
# <class 'str'>
# -1
# hive| apache| itil process| hadoop| big data| aws| core java
# <class 'str'>
# -1
# motor insurance| insurance sales| insurance broking| general insurance
# <class 'str'>
# -1
# SQL|Hibernate|Multithreading|OOAD|Eclipse|Business process|Outsourcing|Version control|Memory management|Control system
# <class 'str'>
# -1
# CATIA| AutoCAD| Pressure vessels| Mechanical| Primavera| PSCAD
# <class 'str'>
# -1
# Team Management| Project Execution| Program Management| Customer Experience| Data Analytics| Supply Chain| Operations Planning
# <class 'str'>
# -1
# business development management| Sales Management
# <class 'str'>
# -1
# Technical support| Outbound| Comp| Technical| Domestic BPO| US shift| process| Inbound calls| Bonus
# <class 'str'>
# -1
# Operations| Inventory Management| Vendor Management| Bhm| Hospitality| Front Office| Guest Relations| Hospitality Management| hotel management
# <class 'str'>
# -1
# financial s| windows| android| mobile development
# <class 'str'>
# -1
# Hardware Board Design| Mixed Signal| Design Engineering
# <class 'str'>
# -1
# environment| functional| operations| business| verbal communication| coaching| analytical skills
# <class 'str'>
# -1
# Screening| Linkedin| IT Recruitment| hr recruitment| Database| recruiter| Sourcing| Interviewing| Recruitment
# <class 'str'>
# -1
# java| linux| server| development| eclipse ide| c| technical| mobile| eclipse| objective c| usability| ui| design| debugging| backend| developer| programming| applications
# <class 'str'>
# -1
# Retail Sales| Sales Executive Activities| Revenue Generation| Inhouse Sales
# <class 'str'>
# -1
# BPO| Customer Support| international bpo| Voice Process| International Voice| International Voice Process
# <class 'str'>
# -1
# J2Ee| Core Java| jQuery| ERP| Tomcat| Eclipse| Open source| Selenium| Computer science| OFBIZ
# <class 'str'>
# -1
# Counselor| Mentor| Trainer| Advisor| Teaching
# <class 'str'>
# -1
# lead generation| branding| business development| Sales Management| market research| competitive intelligence| market analysis| Marketing
# <class 'str'>
# -1
# Wireless| Automation| Simulation| Networking| Aerospace| FPGA| Coding| System verilog| Automotive| Physical design
# <class 'str'>
# -1
# hr| recruitment| recruiter| hiring| head hunting| leadership| mass hiring| volume hiring| bulk hiring| team leader| senior| tl| non it| it recruitment| technical hiring| it recruiter| bfsi| engineering| manufacturing| insurance| bpo| IT
# <class 'str'>
# -1
# Associate
# <class 'str'>
# -1
# javascript| html| sql server| ajax| jquery| soa| oop| english| proactive| asp net c
# <class 'str'>
# -1
# marketing executive| Sales| distributors| customer profiling| sales strategy| market research| Business Development| sales executive
# <class 'str'>
# -1
# QMS| Impex| Environmental Management System| Warehouse Management System| Export Import Logistics
# <class 'str'>
# -1
# Java| core java| J2EE| Hibernate| Spring| LDAP| ADFS| Json| SOAP| jQuery| REST| Javascript| Java Web Services| Java Api| Advanced Java| MVC| Web Services| Open Source| SOA| Cloud| spring integration
# <class 'str'>
# -1
# spring boot| spring security| spring mvc
# <class 'str'>
# -1
# Dynamics CRM| .Net| Azure| Visual Studio| Microsoft Dynamics| Solution Management| Root Cause| microservices| .NET development
# <class 'str'>
# -1
# Marketing Strategy| Strategic Thinking| Interpersonal Communication| Sales| Promotions| Accounting| Account Management| Team Leading| Business Development Management| Advertising
# <class 'str'>
# -1
# O2C|OTC|Order Management|Credit Management|Communication Skills
# <class 'str'>
# -1
# visualization| m e p| modeling| drafting| design development| drawings| cad| preparation| quality
# <class 'str'>
# -1
# pnr| primetime| sta| floorplan| timing closure| synthesis| vlsi| Physical design| floor planning
# <class 'str'>
# -1
# Assistant Manager Purchase
# <class 'str'>
# -1
# SQL|Python| Analytics| Machine learning| Solution architecture| Analytical| SCALA| Cosmos| Programming| Data warehousing
# <class 'str'>
# 4
# BPO| Transactional Quality| Quality Management| Quality manager| manager Quality
# <class 'str'>
# -1
# IIS| Exchange Server| Windows Server| WSS| Sharepoint| Active Directory
# <class 'str'>
# -1
# pharma chemicals| business development| api| intermediates| sales
# <class 'str'>
# -1
# Hibernate| Design Patterns| Cloud| Spring Boot| Team Leader| core java| Web Services| Microservices
# <class 'str'>
# -1
# Exadata| performance tuning| 11g| patching| sql| dataguard| rac| cassandra| oracle database| Weblogic| ebs| asm| apps dba| cloning
# <class 'str'>
# -1
# hospital| pharma| pharmacy
# <class 'str'>
# -1
# Sales| insurance sales| agency sales| Direct sales| life advisor| channel sales| life insurance advisor| life insurance| agency
# <class 'str'>
# -1
# Training Needs| Soft Skills| Accent| HR| Feedback| Coaching| Customer Service| Process Compliance
# <class 'str'>
# -1
# Real Estate Construction| Project Management| Interpersonal Communication| Communication Skills| Project Manager| Project Coordinator| site coordinator
# <class 'str'>
# -1
# international bpo| Chat Process| voice based process| tele caller| process developer| Sales| b.a| exl| communication skills| Ba| Blended Process| bba| wipro| tcs| bbm| customer support| bcom| cse| accenture| Fresher| wns
# <class 'str'>
# -1
# project support| Banking| Maya| E-commerce| big data
# <class 'str'>
# -1
# Networking| It Asset| Antivirus| Hardware Troubleshooting
# <class 'str'>
# -1
# Procurement| Business process| IT services| Automation| data services| Master data management| Consulting| Vendor| Troubleshooting| Business Executive
# <class 'str'>
# -1
# Recruitment| Outbound| Technical support| English| Comp| Email| Troubleshooting| Domestic BPO| International BPO| Inbound calls
# <class 'str'>
# -1
# Photoshop| Illustrator| Fine arts| Software design| User interface designing| game development| creative content| Supervision| Relationship Executive| Business Executive
# <class 'str'>
# -1
# marketing| project management| PR| project planning
# <class 'str'>
# -1
# Leadership training| Software development life cycle| Management
# <class 'str'>
# -1
# Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems
# <class 'str'>
# 0
# apache camel| Administration| Technical Support| redhat| Activemq
# <class 'str'>
# -1
# customer profiling| market research| sales executive| marketing executive| distributors| sales strategy| Business Development
# <class 'str'>
# -1
# customer segmentation| Brand management| Strategic partnerships| Brand marketing| Consumer insights| Performance appraisal| Operations| Promotional strategies| Marketing strategy| Recruitment
# <class 'str'>
# -1
# Negotiation| Marine Operation| Oracle Fusion| Manufacturing| Inventory
# <class 'str'>
# -1
# Fire Safety| fire| Senior Management
# <class 'str'>
# -1
# Unix| data science| SQL| Linux| SAS| HTML| Perl| SDLC| Android|Python
# <class 'str'>
# 63
# Installation|Breakdown Maintenance|Preventive Maintenance
# <class 'str'>
# -1
# dot matrix| printer| printer support| Laserjet| Hardware
# <class 'str'>
# -1
# Outbound| Technical Support Associate| Email| Technical| US shift| Medical| Antivirus| Troubleshooting| Technical support| Comp
# <class 'str'>
# -1
# Reporting| Data Analysis| Business Analytics| Data Analytics| kpo
# <class 'str'>
# -1
# HTML| XML| Ajax| rest| Prototype| technical| developing| JSON| application architecture| SDLC| javascript| jQuery| Web services| java| application| web| design| Web designing| architecture| applications
# <class 'str'>
# -1
# us it recruiter| us it recruitment| us it staffing| us staffing| us technical recruiter| us recruitment
# <class 'str'>
# -1
# service engineering| maintenance| breakdown| shutdown| amc| installation| repair| troubleshooting| field service engineer| Preventive Maintenance| breakdown maintenance| Field Engineer| Electrical Engineer
# <class 'str'>
# -1
# enterprise sales| relationship building| new business| sales strategy| B2B Sales| marketing management| cross selling| product marketing| consultative sales| b2b marketing| service sales| Corporate Sales| Key Accounts Manager
# <class 'str'>
# -1
# accounts executive| Accounting| accounts| finance
# <class 'str'>
# -1
# inbound| costing| selling| good communication| good communication skills| tickets| tour| experience| manager| packages
# <class 'str'>
# -1
# Monthly Reports| Maintenance| Technician Activities| Water Quality
# <class 'str'>
# -1
# kaggle|NLP|data science|Artificial Intelligence|Natural Language Processing|analytical techniques|Text Mining|big data|machine learning|Deep Learning
# <class 'str'>
# -1
# Talent Acquisition| Recruitment| HR| Campus Hiring| recruitment| recruiting
# <class 'str'>
# -1
# Counselor| Mentor| Trainer| Advisor| Teaching
# <class 'str'>
# -1
# project sales| Architects| Sales Operations| Sales Management| distributor| interior designers| Area Management| contractors| Area| Developers| consultants| dealer| territory management| Sales Manager
# <class 'str'>
# -1
# Retail| marketing executive| distributors| customer profiling| sales strategy| SME| market research| Business Development| Operations| sales executive
# <class 'str'>
# -1
# Manager Sales| Sales Manager| assistant sales manager| MICE| Travel Agent| Senior Sales Executive| senior sales officer| Corporate Sales| Hotel Sales| Room Sales| Sales Executive
# <class 'str'>
# -1
# data analysis| vba| macros| advanced excel| oracle sql| google analytics| business analysis|Python| data mining| business analyst
# <class 'str'>
# 92
# C#| CSS| XML| Asp Net| Javascript| Web Application| MS SQL Server| .Net| MVC| ASP.Net MVC| JQuery| Ajax
# <class 'str'>
# -1
# land acquisition
# <class 'str'>
# -1
# Java| Tomcat| Eclipse| OOPS| HTML| UNIX| SQL| DB2| Weblogic| XML| Flex| Oracle| PL
# <class 'str'>
# -1
# cnc| cnc operator| cnc maintenance| cnc programming
# <class 'str'>
# -1
# Medical Representative| Senior Executive
# <class 'str'>
# -1
# Inside Sales| Lead Generation| Cold Calling| New Business| Customer Service| Proposal Writing| Follow Ups| Sales Executive Activities| Communication Skills| Convincing Power
# <class 'str'>
# -1
# Customer Care| Inbound Process| Night Shift| Customer Care Executive| Customer Care Officer| BPO| Domestic BPO| International BPO
# <class 'str'>
# -1
# Performance management| Analytical| Design development| Conceptualization| HR| Continuous improvement| Sales support| Recruitment| Testing
# <class 'str'>
# -1
# Service delivery| Bfsi| enterprise mobility| Market intelligence| Tools| Application development| Sales process| microsoft| Middleware| Business Executive
# <class 'str'>
# -1
# laundry
# <class 'str'>
# -1
# TDS| Financial statements| Invoice processing| business opportunity| Interpersonal skills| Tally ERP| Accounting| Analytical| Accounts receivable| Recruitment
# <class 'str'>
# -1
# ERP| Succession Planning| MIS| Reports| Talent Management| Human Resources| HR Policies| Recruitment| Talent Acquisition
# <class 'str'>
# -1
# T-SQL| Web technologies| data manipulation| MIS| XML| Data structures| System Analyst| JSON| Scripting
# <class 'str'>
# -1
# Audit| Credit Officers| Internal audit| Accounting| Finance| Tax| Accounts| Risk Management
# <class 'str'>
# -1
# gsm| ethernet| development| optimization| product development| troubleshooting| gps| lcd| embedded| spi
# <class 'str'>
# -1
# ...
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# 127.0.0.1 - - [16/Sep/2022 01:20:42] "GET /data?Location=Los+Angeles HTTP/1.1" 200 -
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1
# Detroit
# <class 'str'>
# -1

# %% [markdown]
# ## Authors

# %% [markdown]
# Lakshmi Holla

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Malika Singla\
# Ayushi Jain

# %% [markdown]
# ## Changelog

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description      |
# | ----------------- | ------- | ------------- | ----------------------- |
# | 2022-01-03        | 0.1     | Lakshmi Holla | Created Initial Version |

# %% [markdown]
# Copyright © 2022 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
